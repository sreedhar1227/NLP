# %% [markdown]
# # Regular Expression
#
# A RegEx or Regular Expression, is a sequence of characters that forms a search pattern. RegEx can be used to check if a string contains the specified search pattern

# %%
import re

# %%
# Multiline text
txt = '''Tata motors International Business
A Block, Shivasagar Estate,
Dr. Annie Besant Road,
Worli, Mumbai - 400018
Contact: +91(22) 67577200

Name : Ritesh Verma
Designation: State Service Head
Office: Gurugan
Contact: 8588881784
Email: ritesh.verma@tatamotors.com

Domestic Business
Tata motors Ltd
4th Floor, Ahura Center
82 Mahakali Caves Road
MIDC, Andheri East
mumbai - 400093
Contact: 022-624071010

Mr. Bapusaheb Bhadale
Tata Motots Ltd
4th Floor, Ahura Center
82 Mahakali Caves Road
MIDC, #Andheri East
Mumbai - 400093
Email : b.bhadale@tatamotors1.com'''

# %%
# pattern = re.compile(r'Ltd') #re.compile() method is used to compile a regex pattern
# pattern = re.compile(r'.') # any char
# pattern = re.compile(r'.ai') # any char followed by ai
# pattern = re.compile(r'^Tata')
# pattern = re.compile(r'com$') 
# pattern = re.compile(r'Mu*') # start with M followed by 0 or more u
# pattern = re.compile(r'Mu+') # start with M followed by 1 or more u
# pattern = re.compile(r'40{3}') # start with 4 followed by 3 zeros
# pattern = re.compile(r'(10){2}') # wants a group of digit to be repeated
# pattern = re.compile(r'Mu{1}|I{1}') # start with M followed by 1 u or 1 I

# Special Sequence
#pattern = re.compile(r'\ATata') # String starts with Tata
# pattern = re.compile(r'\bTata') # Word starts with Tata
# pattern = re.compile(r'com\b') # Word ends with com
# pattern = re.compile(r'\d{3}-\d{9}') # I want 3 digits before - and 9 degits after -
# pattern = re.compile(r'[a-z]@[a-z]') # To fetch word containing @
# pattern = re.compile(r'\s') # string contains white space char
# pattern = re.compile(r'\S') # string does not contains white space char

# %%
print('\n')
print(r'\n') # r represent Raw String
# Out:
# \n

# %%
# function matches a pattern in a string and returns an iterator
match = pattern.finditer(txt)

for m in match:
    print(m)
    #print(txt[495:496])
# Out:
# <re.Match object; span=(0, 1), match='T'>
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='t'>
# <re.Match object; span=(3, 4), match='a'>
# <re.Match object; span=(5, 6), match='m'>
# <re.Match object; span=(6, 7), match='o'>
# <re.Match object; span=(7, 8), match='t'>
# <re.Match object; span=(8, 9), match='o'>
# <re.Match object; span=(9, 10), match='r'>
# <re.Match object; span=(10, 11), match='s'>
# <re.Match object; span=(12, 13), match='I'>
# <re.Match object; span=(13, 14), match='n'>
# <re.Match object; span=(14, 15), match='t'>
# <re.Match object; span=(15, 16), match='e'>
# <re.Match object; span=(16, 17), match='r'>
# <re.Match object; span=(17, 18), match='n'>
# <re.Match object; span=(18, 19), match='a'>
# <re.Match object; span=(19, 20), match='t'>
# <re.Match object; span=(20, 21), match='i'>
# <re.Match object; span=(21, 22), match='o'>
# <re.Match object; span=(22, 23), match='n'>
# <re.Match object; span=(23, 24), match='a'>
# <re.Match object; span=(24, 25), match='l'>
# <re.Match object; span=(26, 27), match='B'>
# <re.Match object; span=(27, 28), match='u'>
# <re.Match object; span=(28, 29), match='s'>
# <re.Match object; span=(29, 30), match='i'>
# <re.Match object; span=(30, 31), match='n'>
# <re.Match object; span=(31, 32), match='e'>
# <re.Match object; span=(32, 33), match='s'>
# <re.Match object; span=(33, 34), match='s'>
# <re.Match object; span=(35, 36), match='A'>
# <re.Match object; span=(37, 38), match='B'>
# <re.Match object; span=(38, 39), match='l'>
# <re.Match object; span=(39, 40), match='o'>
# <re.Match object; span=(40, 41), match='c'>
# <re.Match object; span=(41, 42), match='k'>
# <re.Match object; span=(42, 43), match=','>
# <re.Match object; span=(44, 45), match='S'>
# <re.Match object; span=(45, 46), match='h'>
# <re.Match object; span=(46, 47), match='i'>
# <re.Match object; span=(47, 48), match='v'>
# <re.Match object; span=(48, 49), match='a'>
# <re.Match object; span=(49, 50), match='s'>
# <re.Match object; span=(50, 51), match='a'>
# <re.Match object; span=(51, 52), match='g'>
# <re.Match object; span=(52, 53), match='a'>
# <re.Match object; span=(53, 54), match='r'>
# <re.Match object; span=(55, 56), match='E'>
# <re.Match object; span=(56, 57), match='s'>
# <re.Match object; span=(57, 58), match='t'>
# <re.Match object; span=(58, 59), match='a'>
# <re.Match object; span=(59, 60), match='t'>
# <re.Match object; span=(60, 61), match='e'>
# <re.Match object; span=(61, 62), match=','>
# <re.Match object; span=(63, 64), match='D'>
# <re.Match object; span=(64, 65), match='r'>
# <re.Match object; span=(65, 66), match='.'>
# <re.Match object; span=(67, 68), match='A'>
# <re.Match object; span=(68, 69), match='n'>
# <re.Match object; span=(69, 70), match='n'>
# <re.Match object; span=(70, 71), match='i'>
# <re.Match object; span=(71, 72), match='e'>
# <re.Match object; span=(73, 74), match='B'>
# <re.Match object; span=(74, 75), match='e'>
# <re.Match object; span=(75, 76), match='s'>
# <re.Match object; span=(76, 77), match='a'>
# <re.Match object; span=(77, 78), match='n'>
# <re.Match object; span=(78, 79), match='t'>
# <re.Match object; span=(80, 81), match='R'>
# <re.Match object; span=(81, 82), match='o'>
# <re.Match object; span=(82, 83), match='a'>
# <re.Match object; span=(83, 84), match='d'>
# <re.Match object; span=(84, 85), match=','>
# <re.Match object; span=(86, 87), match='W'>
# <re.Match object; span=(87, 88), match='o'>
# <re.Match object; span=(88, 89), match='r'>
# <re.Match object; span=(89, 90), match='l'>
# <re.Match object; span=(90, 91), match='i'>
# <re.Match object; span=(91, 92), match=','>
# <re.Match object; span=(93, 94), match='M'>
# <re.Match object; span=(94, 95), match='u'>
# <re.Match object; span=(95, 96), match='m'>
# <re.Match object; span=(96, 97), match='b'>
# <re.Match object; span=(97, 98), match='a'>
# <re.Match object; span=(98, 99), match='i'>
# <re.Match object; span=(100, 101), match='-'>
# <re.Match object; span=(102, 103), match='4'>
# <re.Match object; span=(103, 104), match='0'>
# <re.Match object; span=(104, 105), match='0'>
# <re.Match object; span=(105, 106), match='0'>
# <re.Match object; span=(106, 107), match='1'>
# <re.Match object; span=(107, 108), match='8'>
# <re.Match object; span=(109, 110), match='C'>
# <re.Match object; span=(110, 111), match='o'>
# <re.Match object; span=(111, 112), match='n'>
# <re.Match object; span=(112, 113), match='t'>
# <re.Match object; span=(113, 114), match='a'>
# <re.Match object; span=(114, 115), match='c'>
# <re.Match object; span=(115, 116), match='t'>
# <re.Match object; span=(116, 117), match=':'>
# <re.Match object; span=(118, 119), match='+'>
# <re.Match object; span=(119, 120), match='9'>
# <re.Match object; span=(120, 121), match='1'>
# <re.Match object; span=(121, 122), match='('>
# <re.Match object; span=(122, 123), match='2'>
# <re.Match object; span=(123, 124), match='2'>
# <re.Match object; span=(124, 125), match=')'>
# <re.Match object; span=(126, 127), match='6'>
# <re.Match object; span=(127, 128), match='7'>
# <re.Match object; span=(128, 129), match='5'>
# <re.Match object; span=(129, 130), match='7'>
# <re.Match object; span=(130, 131), match='7'>
# <re.Match object; span=(131, 132), match='2'>
# <re.Match object; span=(132, 133), match='0'>
# <re.Match object; span=(133, 134), match='0'>
# <re.Match object; span=(136, 137), match='N'>
# <re.Match object; span=(137, 138), match='a'>
# <re.Match object; span=(138, 139), match='m'>
# <re.Match object; span=(139, 140), match='e'>
# <re.Match object; span=(141, 142), match=':'>
# <re.Match object; span=(143, 144), match='R'>
# <re.Match object; span=(144, 145), match='i'>
# <re.Match object; span=(145, 146), match='t'>
# <re.Match object; span=(146, 147), match='e'>
# <re.Match object; span=(147, 148), match='s'>
# <re.Match object; span=(148, 149), match='h'>
# <re.Match object; span=(150, 151), match='V'>
# <re.Match object; span=(151, 152), match='e'>
# <re.Match object; span=(152, 153), match='r'>
# <re.Match object; span=(153, 154), match='m'>
# <re.Match object; span=(154, 155), match='a'>
# <re.Match object; span=(156, 157), match='D'>
# <re.Match object; span=(157, 158), match='e'>
# <re.Match object; span=(158, 159), match='s'>
# <re.Match object; span=(159, 160), match='i'>
# <re.Match object; span=(160, 161), match='g'>
# <re.Match object; span=(161, 162), match='n'>
# <re.Match object; span=(162, 163), match='a'>
# <re.Match object; span=(163, 164), match='t'>
# <re.Match object; span=(164, 165), match='i'>
# <re.Match object; span=(165, 166), match='o'>
# <re.Match object; span=(166, 167), match='n'>
# <re.Match object; span=(167, 168), match=':'>
# <re.Match object; span=(169, 170), match='S'>
# <re.Match object; span=(170, 171), match='t'>
# <re.Match object; span=(171, 172), match='a'>
# <re.Match object; span=(172, 173), match='t'>
# <re.Match object; span=(173, 174), match='e'>
# <re.Match object; span=(175, 176), match='S'>
# <re.Match object; span=(176, 177), match='e'>
# <re.Match object; span=(177, 178), match='r'>
# <re.Match object; span=(178, 179), match='v'>
# <re.Match object; span=(179, 180), match='i'>
# <re.Match object; span=(180, 181), match='c'>
# <re.Match object; span=(181, 182), match='e'>
# <re.Match object; span=(183, 184), match='H'>
# <re.Match object; span=(184, 185), match='e'>
# <re.Match object; span=(185, 186), match='a'>
# <re.Match object; span=(186, 187), match='d'>
# <re.Match object; span=(188, 189), match='O'>
# <re.Match object; span=(189, 190), match='f'>
# <re.Match object; span=(190, 191), match='f'>
# <re.Match object; span=(191, 192), match='i'>
# <re.Match object; span=(192, 193), match='c'>
# <re.Match object; span=(193, 194), match='e'>
# <re.Match object; span=(194, 195), match=':'>
# <re.Match object; span=(196, 197), match='G'>
# <re.Match object; span=(197, 198), match='u'>
# <re.Match object; span=(198, 199), match='r'>
# <re.Match object; span=(199, 200), match='u'>
# <re.Match object; span=(200, 201), match='g'>
# <re.Match object; span=(201, 202), match='a'>
# <re.Match object; span=(202, 203), match='n'>
# <re.Match object; span=(204, 205), match='C'>
# <re.Match object; span=(205, 206), match='o'>
# <re.Match object; span=(206, 207), match='n'>
# <re.Match object; span=(207, 208), match='t'>
# <re.Match object; span=(208, 209), match='a'>
# <re.Match object; span=(209, 210), match='c'>
# <re.Match object; span=(210, 211), match='t'>
# <re.Match object; span=(211, 212), match=':'>
# <re.Match object; span=(213, 214), match='8'>
# <re.Match object; span=(214, 215), match='5'>
# <re.Match object; span=(215, 216), match='8'>
# <re.Match object; span=(216, 217), match='8'>
# <re.Match object; span=(217, 218), match='8'>
# <re.Match object; span=(218, 219), match='8'>
# <re.Match object; span=(219, 220), match='1'>
# <re.Match object; span=(220, 221), match='7'>
# <re.Match object; span=(221, 222), match='8'>
# <re.Match object; span=(222, 223), match='4'>
# <re.Match object; span=(224, 225), match='E'>
# <re.Match object; span=(225, 226), match='m'>
# <re.Match object; span=(226, 227), match='a'>
# <re.Match object; span=(227, 228), match='i'>
# <re.Match object; span=(228, 229), match='l'>
# <re.Match object; span=(229, 230), match=':'>
# <re.Match object; span=(231, 232), match='r'>
# <re.Match object; span=(232, 233), match='i'>
# <re.Match object; span=(233, 234), match='t'>
# <re.Match object; span=(234, 235), match='e'>
# <re.Match object; span=(235, 236), match='s'>
# <re.Match object; span=(236, 237), match='h'>
# <re.Match object; span=(237, 238), match='.'>
# <re.Match object; span=(238, 239), match='v'>
# <re.Match object; span=(239, 240), match='e'>
# <re.Match object; span=(240, 241), match='r'>
# <re.Match object; span=(241, 242), match='m'>
# <re.Match object; span=(242, 243), match='a'>
# <re.Match object; span=(243, 244), match='@'>
# <re.Match object; span=(244, 245), match='t'>
# <re.Match object; span=(245, 246), match='a'>
# <re.Match object; span=(246, 247), match='t'>
# <re.Match object; span=(247, 248), match='a'>
# <re.Match object; span=(248, 249), match='m'>
# <re.Match object; span=(249, 250), match='o'>
# <re.Match object; span=(250, 251), match='t'>
# <re.Match object; span=(251, 252), match='o'>
# <re.Match object; span=(252, 253), match='r'>
# <re.Match object; span=(253, 254), match='s'>
# <re.Match object; span=(254, 255), match='.'>
# <re.Match object; span=(255, 256), match='c'>
# <re.Match object; span=(256, 257), match='o'>
# <re.Match object; span=(257, 258), match='m'>
# <re.Match object; span=(260, 261), match='D'>
# <re.Match object; span=(261, 262), match='o'>
# <re.Match object; span=(262, 263), match='m'>
# <re.Match object; span=(263, 264), match='e'>
# <re.Match object; span=(264, 265), match='s'>
# <re.Match object; span=(265, 266), match='t'>
# <re.Match object; span=(266, 267), match='i'>
# <re.Match object; span=(267, 268), match='c'>
# <re.Match object; span=(269, 270), match='B'>
# <re.Match object; span=(270, 271), match='u'>
# <re.Match object; span=(271, 272), match='s'>
# <re.Match object; span=(272, 273), match='i'>
# <re.Match object; span=(273, 274), match='n'>
# <re.Match object; span=(274, 275), match='e'>
# <re.Match object; span=(275, 276), match='s'>
# <re.Match object; span=(276, 277), match='s'>
# <re.Match object; span=(278, 279), match='T'>
# <re.Match object; span=(279, 280), match='a'>
# <re.Match object; span=(280, 281), match='t'>
# <re.Match object; span=(281, 282), match='a'>
# <re.Match object; span=(283, 284), match='m'>
# <re.Match object; span=(284, 285), match='o'>
# <re.Match object; span=(285, 286), match='t'>
# <re.Match object; span=(286, 287), match='o'>
# <re.Match object; span=(287, 288), match='r'>
# <re.Match object; span=(288, 289), match='s'>
# <re.Match object; span=(290, 291), match='L'>
# <re.Match object; span=(291, 292), match='t'>
# <re.Match object; span=(292, 293), match='d'>
# <re.Match object; span=(294, 295), match='4'>
# <re.Match object; span=(295, 296), match='t'>
# <re.Match object; span=(296, 297), match='h'>
# <re.Match object; span=(298, 299), match='F'>
# <re.Match object; span=(299, 300), match='l'>
# <re.Match object; span=(300, 301), match='o'>
# <re.Match object; span=(301, 302), match='o'>
# <re.Match object; span=(302, 303), match='r'>
# <re.Match object; span=(303, 304), match=','>
# <re.Match object; span=(305, 306), match='A'>
# <re.Match object; span=(306, 307), match='h'>
# <re.Match object; span=(307, 308), match='u'>
# <re.Match object; span=(308, 309), match='r'>
# <re.Match object; span=(309, 310), match='a'>
# <re.Match object; span=(311, 312), match='C'>
# <re.Match object; span=(312, 313), match='e'>
# <re.Match object; span=(313, 314), match='n'>
# <re.Match object; span=(314, 315), match='t'>
# <re.Match object; span=(315, 316), match='e'>
# <re.Match object; span=(316, 317), match='r'>
# <re.Match object; span=(318, 319), match='8'>
# <re.Match object; span=(319, 320), match='2'>
# <re.Match object; span=(321, 322), match='M'>
# <re.Match object; span=(322, 323), match='a'>
# <re.Match object; span=(323, 324), match='h'>
# <re.Match object; span=(324, 325), match='a'>
# <re.Match object; span=(325, 326), match='k'>
# <re.Match object; span=(326, 327), match='a'>
# <re.Match object; span=(327, 328), match='l'>
# <re.Match object; span=(328, 329), match='i'>
# <re.Match object; span=(330, 331), match='C'>
# <re.Match object; span=(331, 332), match='a'>
# <re.Match object; span=(332, 333), match='v'>
# <re.Match object; span=(333, 334), match='e'>
# <re.Match object; span=(334, 335), match='s'>
# <re.Match object; span=(336, 337), match='R'>
# <re.Match object; span=(337, 338), match='o'>
# <re.Match object; span=(338, 339), match='a'>
# <re.Match object; span=(339, 340), match='d'>
# <re.Match object; span=(341, 342), match='M'>
# <re.Match object; span=(342, 343), match='I'>
# <re.Match object; span=(343, 344), match='D'>
# <re.Match object; span=(344, 345), match='C'>
# <re.Match object; span=(345, 346), match=','>
# <re.Match object; span=(347, 348), match='A'>
# <re.Match object; span=(348, 349), match='n'>
# <re.Match object; span=(349, 350), match='d'>
# <re.Match object; span=(350, 351), match='h'>
# <re.Match object; span=(351, 352), match='e'>
# <re.Match object; span=(352, 353), match='r'>
# <re.Match object; span=(353, 354), match='i'>
# <re.Match object; span=(355, 356), match='E'>
# <re.Match object; span=(356, 357), match='a'>
# <re.Match object; span=(357, 358), match='s'>
# <re.Match object; span=(358, 359), match='t'>
# <re.Match object; span=(360, 361), match='m'>
# <re.Match object; span=(361, 362), match='u'>
# <re.Match object; span=(362, 363), match='m'>
# <re.Match object; span=(363, 364), match='b'>
# <re.Match object; span=(364, 365), match='a'>
# <re.Match object; span=(365, 366), match='i'>
# <re.Match object; span=(367, 368), match='-'>
# <re.Match object; span=(369, 370), match='4'>
# <re.Match object; span=(370, 371), match='0'>
# <re.Match object; span=(371, 372), match='0'>
# <re.Match object; span=(372, 373), match='0'>
# <re.Match object; span=(373, 374), match='9'>
# <re.Match object; span=(374, 375), match='3'>
# <re.Match object; span=(376, 377), match='C'>
# <re.Match object; span=(377, 378), match='o'>
# <re.Match object; span=(378, 379), match='n'>
# <re.Match object; span=(379, 380), match='t'>
# <re.Match object; span=(380, 381), match='a'>
# <re.Match object; span=(381, 382), match='c'>
# <re.Match object; span=(382, 383), match='t'>
# <re.Match object; span=(383, 384), match=':'>
# <re.Match object; span=(385, 386), match='0'>
# <re.Match object; span=(386, 387), match='2'>
# <re.Match object; span=(387, 388), match='2'>
# <re.Match object; span=(388, 389), match='-'>
# <re.Match object; span=(389, 390), match='6'>
# <re.Match object; span=(390, 391), match='2'>
# <re.Match object; span=(391, 392), match='4'>
# <re.Match object; span=(392, 393), match='0'>
# <re.Match object; span=(393, 394), match='7'>
# <re.Match object; span=(394, 395), match='1'>
# <re.Match object; span=(395, 396), match='0'>
# <re.Match object; span=(396, 397), match='1'>
# <re.Match object; span=(397, 398), match='0'>
# <re.Match object; span=(400, 401), match='M'>
# <re.Match object; span=(401, 402), match='r'>
# <re.Match object; span=(402, 403), match='.'>
# <re.Match object; span=(404, 405), match='B'>
# <re.Match object; span=(405, 406), match='a'>
# <re.Match object; span=(406, 407), match='p'>
# <re.Match object; span=(407, 408), match='u'>
# <re.Match object; span=(408, 409), match='s'>
# <re.Match object; span=(409, 410), match='a'>
# <re.Match object; span=(410, 411), match='h'>
# <re.Match object; span=(411, 412), match='e'>
# <re.Match object; span=(412, 413), match='b'>
# <re.Match object; span=(414, 415), match='B'>
# <re.Match object; span=(415, 416), match='h'>
# <re.Match object; span=(416, 417), match='a'>
# <re.Match object; span=(417, 418), match='d'>
# <re.Match object; span=(418, 419), match='a'>
# <re.Match object; span=(419, 420), match='l'>
# <re.Match object; span=(420, 421), match='e'>
# <re.Match object; span=(422, 423), match='T'>
# <re.Match object; span=(423, 424), match='a'>
# <re.Match object; span=(424, 425), match='t'>
# <re.Match object; span=(425, 426), match='a'>
# <re.Match object; span=(427, 428), match='M'>
# <re.Match object; span=(428, 429), match='o'>
# <re.Match object; span=(429, 430), match='t'>
# <re.Match object; span=(430, 431), match='o'>
# <re.Match object; span=(431, 432), match='t'>
# <re.Match object; span=(432, 433), match='s'>
# <re.Match object; span=(434, 435), match='L'>
# <re.Match object; span=(435, 436), match='t'>
# <re.Match object; span=(436, 437), match='d'>
# <re.Match object; span=(438, 439), match='4'>
# <re.Match object; span=(439, 440), match='t'>
# <re.Match object; span=(440, 441), match='h'>
# <re.Match object; span=(442, 443), match='F'>
# <re.Match object; span=(443, 444), match='l'>
# <re.Match object; span=(444, 445), match='o'>
# <re.Match object; span=(445, 446), match='o'>
# <re.Match object; span=(446, 447), match='r'>
# <re.Match object; span=(447, 448), match=','>
# <re.Match object; span=(449, 450), match='A'>
# <re.Match object; span=(450, 451), match='h'>
# <re.Match object; span=(451, 452), match='u'>
# <re.Match object; span=(452, 453), match='r'>
# <re.Match object; span=(453, 454), match='a'>
# <re.Match object; span=(455, 456), match='C'>
# <re.Match object; span=(456, 457), match='e'>
# <re.Match object; span=(457, 458), match='n'>
# <re.Match object; span=(458, 459), match='t'>
# <re.Match object; span=(459, 460), match='e'>
# <re.Match object; span=(460, 461), match='r'>
# <re.Match object; span=(462, 463), match='8'>
# <re.Match object; span=(463, 464), match='2'>
# <re.Match object; span=(465, 466), match='M'>
# <re.Match object; span=(466, 467), match='a'>
# <re.Match object; span=(467, 468), match='h'>
# <re.Match object; span=(468, 469), match='a'>
# <re.Match object; span=(469, 470), match='k'>
# <re.Match object; span=(470, 471), match='a'>
# <re.Match object; span=(471, 472), match='l'>
# <re.Match object; span=(472, 473), match='i'>
# <re.Match object; span=(474, 475), match='C'>
# <re.Match object; span=(475, 476), match='a'>
# <re.Match object; span=(476, 477), match='v'>
# <re.Match object; span=(477, 478), match='e'>
# <re.Match object; span=(478, 479), match='s'>
# <re.Match object; span=(480, 481), match='R'>
# <re.Match object; span=(481, 482), match='o'>
# <re.Match object; span=(482, 483), match='a'>
# <re.Match object; span=(483, 484), match='d'>
# <re.Match object; span=(485, 486), match='M'>
# <re.Match object; span=(486, 487), match='I'>
# <re.Match object; span=(487, 488), match='D'>
# <re.Match object; span=(488, 489), match='C'>
# <re.Match object; span=(489, 490), match=','>
# <re.Match object; span=(491, 492), match='#'>
# <re.Match object; span=(492, 493), match='A'>
# <re.Match object; span=(493, 494), match='n'>
# <re.Match object; span=(494, 495), match='d'>
# <re.Match object; span=(495, 496), match='h'>
# <re.Match object; span=(496, 497), match='e'>
# <re.Match object; span=(497, 498), match='r'>
# <re.Match object; span=(498, 499), match='i'>
# <re.Match object; span=(500, 501), match='E'>
# <re.Match object; span=(501, 502), match='a'>
# <re.Match object; span=(502, 503), match='s'>
# <re.Match object; span=(503, 504), match='t'>
# <re.Match object; span=(505, 506), match='M'>
# <re.Match object; span=(506, 507), match='u'>
# <re.Match object; span=(507, 508), match='m'>
# <re.Match object; span=(508, 509), match='b'>
# <re.Match object; span=(509, 510), match='a'>
# <re.Match object; span=(510, 511), match='i'>
# <re.Match object; span=(512, 513), match='-'>
# <re.Match object; span=(514, 515), match='4'>
# <re.Match object; span=(515, 516), match='0'>
# <re.Match object; span=(516, 517), match='0'>
# <re.Match object; span=(517, 518), match='0'>
# <re.Match object; span=(518, 519), match='9'>
# <re.Match object; span=(519, 520), match='3'>
# <re.Match object; span=(521, 522), match='E'>
# <re.Match object; span=(522, 523), match='m'>
# <re.Match object; span=(523, 524), match='a'>
# <re.Match object; span=(524, 525), match='i'>
# <re.Match object; span=(525, 526), match='l'>
# <re.Match object; span=(527, 528), match=':'>
# <re.Match object; span=(529, 530), match='b'>
# <re.Match object; span=(530, 531), match='.'>
# <re.Match object; span=(531, 532), match='b'>
# <re.Match object; span=(532, 533), match='h'>
# <re.Match object; span=(533, 534), match='a'>
# <re.Match object; span=(534, 535), match='d'>
# <re.Match object; span=(535, 536), match='a'>
# <re.Match object; span=(536, 537), match='l'>
# <re.Match object; span=(537, 538), match='e'>
# <re.Match object; span=(538, 539), match='@'>
# <re.Match object; span=(539, 540), match='t'>
# <re.Match object; span=(540, 541), match='a'>
# <re.Match object; span=(541, 542), match='t'>
# <re.Match object; span=(542, 543), match='a'>
# <re.Match object; span=(543, 544), match='m'>
# <re.Match object; span=(544, 545), match='o'>
# <re.Match object; span=(545, 546), match='t'>
# <re.Match object; span=(546, 547), match='o'>
# <re.Match object; span=(547, 548), match='r'>
# <re.Match object; span=(548, 549), match='s'>
# <re.Match object; span=(549, 550), match='1'>
# <re.Match object; span=(550, 551), match='.'>
# <re.Match object; span=(551, 552), match='c'>
# <re.Match object; span=(552, 553), match='o'>
# <re.Match object; span=(553, 554), match='m'>
