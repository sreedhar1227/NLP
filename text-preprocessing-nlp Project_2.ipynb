# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Generative AI\NLP_For_Gen_AI\aws_review_sofware_dataset.csv",nrows=100)

# %%
df
# Out:
#     Unnamed: 0  overall  verified   reviewTime      reviewerID       asin  \
# 0            0      4.0      True  03 11, 2014  A240ORQ2LF9LUI   77613252
# 1            1      4.0      True  02 23, 2014  A1YCCU0YRLS0FE   77613252
# 2            2      1.0      True  02 17, 2014  A1BJHRQDYVAY2J   77613252
# 3            3      3.0      True  02 17, 2014   APRDVZ6QBIQXT   77613252
# 4            4      5.0     False  10 14, 2013  A2JZTTBSLS1QXV   77775473
# ..         ...      ...       ...          ...             ...        ...
# 95          95      4.0     False   04 8, 2008  A27PAMABWVQ892  615179088
# 96          96      5.0     False  03 26, 2008  A3HWWVK0L3JEKF  615179088
# 97          97      5.0     False  02 20, 2008  A3NO2V2JU4Y8UY  615179088
# 98          98      5.0     False  02 11, 2008  A3IMKYBNIGFPG9  615179088
# 99          99      5.0     False  01 19, 2008  A172Z0OZZD2UVF  615179088
#
#                          style         reviewerName  \
# 0   {'Format:': ' Loose Leaf'}           Michelle W
# 1   {'Format:': ' Loose Leaf'}  Rosalind White Ames
# 2   {'Format:': ' Loose Leaf'}       Allan R. Baker
# 3   {'Format:': ' Loose Leaf'}                 Lucy
# 4                          NaN            Albert V.
# ..                         ...                  ...
# 95                         NaN          piepiepie75
# 96                         NaN             K. Grier
# 97                         NaN            H. Granat
# 98                         NaN    Kenneth S. French
# 99                         NaN       Lee W. Hericks
#
#                                            reviewText  \
# 0   The materials arrived early and were in excell...
# 1   I am really enjoying this book with the worksh...
# 2   IF YOU ARE TAKING THIS CLASS DON"T WASTE YOUR ...
# 3   This book was missing pages!!! Important pages...
# 4   I have used LearnSmart and can officially say ...
# ..                                                ...
# 95  My first experience with Human Japanese was th...
# 96  This is the first language software that I hav...
# 97  Human japanese is the best pc program for lear...
# 98  If you want to learn or teach Japanese I would...
# 99  Human Japanese has an elegant, yet simple user...
#
#                                               summary  unixReviewTime   vote  \
# 0                                      Material Great      1394496000    NaN
# 1                                              Health      1393113600    NaN
# 2                                  ARE YOU KIDING ME?      1392595200    7.0
# 3                                     missing pages!!      1392595200    3.0
# 4                       Best study product out there!      1381708800    NaN
# ..                                                ...             ...    ...
# 95  Better than the Human Japanese 1...but not muc...      1207612800   99.0
# 96                                      Great Product      1206489600    4.0
# 97                                           Love it!      1203465600    2.0
# 98                           Outstanding, easy-to-use      1202688000    5.0
# 99     Learning a foreign language with a human touch      1200700800  246.0
#
#    image
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
#
# [100 rows x 13 columns]

# %% [markdown]
# # Lower Casing

# %%
df['style'] = df['style'].str.lower()
df['reviewerName'] = df['reviewerName'].str.lower()
df['reviewText'] = df['reviewText'].str.lower()
df['summary'] = df['summary'].str.lower()

# %%
df
# Out:
#     Unnamed: 0  overall  verified   reviewTime      reviewerID       asin  \
# 0            0      4.0      True  03 11, 2014  A240ORQ2LF9LUI   77613252
# 1            1      4.0      True  02 23, 2014  A1YCCU0YRLS0FE   77613252
# 2            2      1.0      True  02 17, 2014  A1BJHRQDYVAY2J   77613252
# 3            3      3.0      True  02 17, 2014   APRDVZ6QBIQXT   77613252
# 4            4      5.0     False  10 14, 2013  A2JZTTBSLS1QXV   77775473
# ..         ...      ...       ...          ...             ...        ...
# 95          95      4.0     False   04 8, 2008  A27PAMABWVQ892  615179088
# 96          96      5.0     False  03 26, 2008  A3HWWVK0L3JEKF  615179088
# 97          97      5.0     False  02 20, 2008  A3NO2V2JU4Y8UY  615179088
# 98          98      5.0     False  02 11, 2008  A3IMKYBNIGFPG9  615179088
# 99          99      5.0     False  01 19, 2008  A172Z0OZZD2UVF  615179088
#
#                          style         reviewerName  \
# 0   {'format:': ' loose leaf'}           michelle w
# 1   {'format:': ' loose leaf'}  rosalind white ames
# 2   {'format:': ' loose leaf'}       allan r. baker
# 3   {'format:': ' loose leaf'}                 lucy
# 4                          NaN            albert v.
# ..                         ...                  ...
# 95                         NaN          piepiepie75
# 96                         NaN             k. grier
# 97                         NaN            h. granat
# 98                         NaN    kenneth s. french
# 99                         NaN       lee w. hericks
#
#                                            reviewText  \
# 0   the materials arrived early and were in excell...
# 1   i am really enjoying this book with the worksh...
# 2   if you are taking this class don"t waste your ...
# 3   this book was missing pages!!! important pages...
# 4   i have used learnsmart and can officially say ...
# ..                                                ...
# 95  my first experience with human japanese was th...
# 96  this is the first language software that i hav...
# 97  human japanese is the best pc program for lear...
# 98  if you want to learn or teach japanese i would...
# 99  human japanese has an elegant, yet simple user...
#
#                                               summary  unixReviewTime   vote  \
# 0                                      material great      1394496000    NaN
# 1                                              health      1393113600    NaN
# 2                                  are you kiding me?      1392595200    7.0
# 3                                     missing pages!!      1392595200    3.0
# 4                       best study product out there!      1381708800    NaN
# ..                                                ...             ...    ...
# 95  better than the human japanese 1...but not muc...      1207612800   99.0
# 96                                      great product      1206489600    4.0
# 97                                           love it!      1203465600    2.0
# 98                           outstanding, easy-to-use      1202688000    5.0
# 99     learning a foreign language with a human touch      1200700800  246.0
#
#    image
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
#
# [100 rows x 13 columns]

# %% [markdown]
# # Remove HTML Tags

# %%
import re  #Regular Expressions
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text)

# %%
df['reviewerName'] = df['reviewerName'].apply(remove_html_tags)
df['reviewText'] = df['reviewText'].apply(remove_html_tags)
df['summary'] = df['summary'].apply(remove_html_tags)
df['reviewerID'] = df['reviewerID'].apply(remove_html_tags)

# %%
df
# Out:
#     Unnamed: 0  overall  verified   reviewTime      reviewerID       asin  \
# 0            0      4.0      True  03 11, 2014  A240ORQ2LF9LUI   77613252
# 1            1      4.0      True  02 23, 2014  A1YCCU0YRLS0FE   77613252
# 2            2      1.0      True  02 17, 2014  A1BJHRQDYVAY2J   77613252
# 3            3      3.0      True  02 17, 2014   APRDVZ6QBIQXT   77613252
# 4            4      5.0     False  10 14, 2013  A2JZTTBSLS1QXV   77775473
# ..         ...      ...       ...          ...             ...        ...
# 95          95      4.0     False   04 8, 2008  A27PAMABWVQ892  615179088
# 96          96      5.0     False  03 26, 2008  A3HWWVK0L3JEKF  615179088
# 97          97      5.0     False  02 20, 2008  A3NO2V2JU4Y8UY  615179088
# 98          98      5.0     False  02 11, 2008  A3IMKYBNIGFPG9  615179088
# 99          99      5.0     False  01 19, 2008  A172Z0OZZD2UVF  615179088
#
#                          style         reviewerName  \
# 0   {'format:': ' loose leaf'}           michelle w
# 1   {'format:': ' loose leaf'}  rosalind white ames
# 2   {'format:': ' loose leaf'}       allan r. baker
# 3   {'format:': ' loose leaf'}                 lucy
# 4                          NaN            albert v.
# ..                         ...                  ...
# 95                         NaN          piepiepie75
# 96                         NaN             k. grier
# 97                         NaN            h. granat
# 98                         NaN    kenneth s. french
# 99                         NaN       lee w. hericks
#
#                                            reviewText  \
# 0   the materials arrived early and were in excell...
# 1   i am really enjoying this book with the worksh...
# 2   if you are taking this class don"t waste your ...
# 3   this book was missing pages!!! important pages...
# 4   i have used learnsmart and can officially say ...
# ..                                                ...
# 95  my first experience with human japanese was th...
# 96  this is the first language software that i hav...
# 97  human japanese is the best pc program for lear...
# 98  if you want to learn or teach japanese i would...
# 99  human japanese has an elegant, yet simple user...
#
#                                               summary  unixReviewTime   vote  \
# 0                                      material great      1394496000    NaN
# 1                                              health      1393113600    NaN
# 2                                  are you kiding me?      1392595200    7.0
# 3                                     missing pages!!      1392595200    3.0
# 4                       best study product out there!      1381708800    NaN
# ..                                                ...             ...    ...
# 95  better than the human japanese 1...but not muc...      1207612800   99.0
# 96                                      great product      1206489600    4.0
# 97                                           love it!      1203465600    2.0
# 98                           outstanding, easy-to-use      1202688000    5.0
# 99     learning a foreign language with a human touch      1200700800  246.0
#
#    image
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
#
# [100 rows x 13 columns]

# %% [markdown]
# # Remove URLs

# %%
def remove_url(text):
    pattern = re.compile(r'https?://\S+|www.\.\S+')
    return pattern.sub(r'', text)

# %%
df['reviewerName'] = df['reviewerName'].apply(remove_url)
df['reviewText'] = df['reviewText'].apply(remove_url)
df['summary'] = df['summary'].apply(remove_url)
df['reviewerID'] = df['reviewerID'].apply(remove_url)

# %%
df
# Out:
#     Unnamed: 0  overall  verified   reviewTime      reviewerID       asin  \
# 0            0      4.0      True  03 11, 2014  A240ORQ2LF9LUI   77613252
# 1            1      4.0      True  02 23, 2014  A1YCCU0YRLS0FE   77613252
# 2            2      1.0      True  02 17, 2014  A1BJHRQDYVAY2J   77613252
# 3            3      3.0      True  02 17, 2014   APRDVZ6QBIQXT   77613252
# 4            4      5.0     False  10 14, 2013  A2JZTTBSLS1QXV   77775473
# ..         ...      ...       ...          ...             ...        ...
# 95          95      4.0     False   04 8, 2008  A27PAMABWVQ892  615179088
# 96          96      5.0     False  03 26, 2008  A3HWWVK0L3JEKF  615179088
# 97          97      5.0     False  02 20, 2008  A3NO2V2JU4Y8UY  615179088
# 98          98      5.0     False  02 11, 2008  A3IMKYBNIGFPG9  615179088
# 99          99      5.0     False  01 19, 2008  A172Z0OZZD2UVF  615179088
#
#                          style         reviewerName  \
# 0   {'format:': ' loose leaf'}           michelle w
# 1   {'format:': ' loose leaf'}  rosalind white ames
# 2   {'format:': ' loose leaf'}       allan r. baker
# 3   {'format:': ' loose leaf'}                 lucy
# 4                          NaN            albert v.
# ..                         ...                  ...
# 95                         NaN          piepiepie75
# 96                         NaN             k. grier
# 97                         NaN            h. granat
# 98                         NaN    kenneth s. french
# 99                         NaN       lee w. hericks
#
#                                            reviewText  \
# 0   the materials arrived early and were in excell...
# 1   i am really enjoying this book with the worksh...
# 2   if you are taking this class don"t waste your ...
# 3   this book was missing pages!!! important pages...
# 4   i have used learnsmart and can officially say ...
# ..                                                ...
# 95  my first experience with human japanese was th...
# 96  this is the first language software that i hav...
# 97  human japanese is the best pc program for lear...
# 98  if you want to learn or teach japanese i would...
# 99  human japanese has an elegant, yet simple user...
#
#                                               summary  unixReviewTime   vote  \
# 0                                      material great      1394496000    NaN
# 1                                              health      1393113600    NaN
# 2                                  are you kiding me?      1392595200    7.0
# 3                                     missing pages!!      1392595200    3.0
# 4                       best study product out there!      1381708800    NaN
# ..                                                ...             ...    ...
# 95  better than the human japanese 1...but not muc...      1207612800   99.0
# 96                                      great product      1206489600    4.0
# 97                                           love it!      1203465600    2.0
# 98                           outstanding, easy-to-use      1202688000    5.0
# 99     learning a foreign language with a human touch      1200700800  246.0
#
#    image
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
#
# [100 rows x 13 columns]

# %% [markdown]
# # Remove Punctuaton

# %%
import string,time
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude = string.punctuation

# %%
def remove_punc1(text):
    return text.translate(str.maketrans('','',exclude))

# %%
df['reviewerName'] = df['reviewerName'].apply(remove_punc1)
df['reviewText'] = df['reviewText'].apply(remove_punc1)
df['summary'] = df['summary'].apply(remove_punc1)
df['reviewerID'] = df['reviewerID'].apply(remove_punc1)

# %%
df
# Out:
#     Unnamed: 0  overall  verified   reviewTime      reviewerID       asin  \
# 0            0      4.0      True  03 11, 2014  A240ORQ2LF9LUI   77613252
# 1            1      4.0      True  02 23, 2014  A1YCCU0YRLS0FE   77613252
# 2            2      1.0      True  02 17, 2014  A1BJHRQDYVAY2J   77613252
# 3            3      3.0      True  02 17, 2014   APRDVZ6QBIQXT   77613252
# 4            4      5.0     False  10 14, 2013  A2JZTTBSLS1QXV   77775473
# ..         ...      ...       ...          ...             ...        ...
# 95          95      4.0     False   04 8, 2008  A27PAMABWVQ892  615179088
# 96          96      5.0     False  03 26, 2008  A3HWWVK0L3JEKF  615179088
# 97          97      5.0     False  02 20, 2008  A3NO2V2JU4Y8UY  615179088
# 98          98      5.0     False  02 11, 2008  A3IMKYBNIGFPG9  615179088
# 99          99      5.0     False  01 19, 2008  A172Z0OZZD2UVF  615179088
#
#                          style         reviewerName  \
# 0   {'format:': ' loose leaf'}           michelle w
# 1   {'format:': ' loose leaf'}  rosalind white ames
# 2   {'format:': ' loose leaf'}        allan r baker
# 3   {'format:': ' loose leaf'}                 lucy
# 4                          NaN             albert v
# ..                         ...                  ...
# 95                         NaN          piepiepie75
# 96                         NaN              k grier
# 97                         NaN             h granat
# 98                         NaN     kenneth s french
# 99                         NaN        lee w hericks
#
#                                            reviewText  \
# 0   the materials arrived early and were in excell...
# 1   i am really enjoying this book with the worksh...
# 2   if you are taking this class dont waste your m...
# 3   this book was missing pages important pages i ...
# 4   i have used learnsmart and can officially say ...
# ..                                                ...
# 95  my first experience with human japanese was th...
# 96  this is the first language software that i hav...
# 97  human japanese is the best pc program for lear...
# 98  if you want to learn or teach japanese i would...
# 99  human japanese has an elegant yet simple user ...
#
#                                               summary  unixReviewTime   vote  \
# 0                                      material great      1394496000    NaN
# 1                                              health      1393113600    NaN
# 2                                   are you kiding me      1392595200    7.0
# 3                                       missing pages      1392595200    3.0
# 4                        best study product out there      1381708800    NaN
# ..                                                ...             ...    ...
# 95  better than the human japanese 1but not much c...      1207612800   99.0
# 96                                      great product      1206489600    4.0
# 97                                            love it      1203465600    2.0
# 98                              outstanding easytouse      1202688000    5.0
# 99     learning a foreign language with a human touch      1200700800  246.0
#
#    image
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
#
# [100 rows x 13 columns]

# %% [markdown]
# # Removing Stop Words

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
def remove_stopwords(text):
    new_text = []
    
    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

# %%
df['reviewerName'] = df['reviewerName'].apply(remove_stopwords)
df['reviewText'] = df['reviewText'].apply(remove_stopwords)
df['summary'] = df['summary'].apply(remove_stopwords)
df['reviewerID'] = df['reviewerID'].apply(remove_stopwords)

# %%
df
# Out:
#     Unnamed: 0  overall  verified   reviewTime      reviewerID       asin  \
# 0            0      4.0      True  03 11, 2014  A240ORQ2LF9LUI   77613252
# 1            1      4.0      True  02 23, 2014  A1YCCU0YRLS0FE   77613252
# 2            2      1.0      True  02 17, 2014  A1BJHRQDYVAY2J   77613252
# 3            3      3.0      True  02 17, 2014   APRDVZ6QBIQXT   77613252
# 4            4      5.0     False  10 14, 2013  A2JZTTBSLS1QXV   77775473
# ..         ...      ...       ...          ...             ...        ...
# 95          95      4.0     False   04 8, 2008  A27PAMABWVQ892  615179088
# 96          96      5.0     False  03 26, 2008  A3HWWVK0L3JEKF  615179088
# 97          97      5.0     False  02 20, 2008  A3NO2V2JU4Y8UY  615179088
# 98          98      5.0     False  02 11, 2008  A3IMKYBNIGFPG9  615179088
# 99          99      5.0     False  01 19, 2008  A172Z0OZZD2UVF  615179088
#
#                          style         reviewerName  \
# 0   {'format:': ' loose leaf'}           michelle w
# 1   {'format:': ' loose leaf'}  rosalind white ames
# 2   {'format:': ' loose leaf'}        allan r baker
# 3   {'format:': ' loose leaf'}                 lucy
# 4                          NaN             albert v
# ..                         ...                  ...
# 95                         NaN          piepiepie75
# 96                         NaN              k grier
# 97                         NaN             h granat
# 98                         NaN       kenneth french
# 99                         NaN        lee w hericks
#
#                                            reviewText  \
# 0   materials arrived early excellent condition ho...
# 1   really enjoying book worksheets make review go...
# 2   taking class dont waste money called book 1400...
# 3   book missing pages important pages couldnt ans...
# 4   used learnsmart officially say amazing study t...
# ..                                                ...
# 95  first experience human japanese first version ...
# 96  first language software purchased love way inf...
# 97  human japanese best pc program learning japane...
# 98  want learn teach japanese would highly recomme...
# 99  human japanese elegant yet simple user interfa...
#
#                                     summary  unixReviewTime   vote image
# 0                            material great      1394496000    NaN   NaN
# 1                                    health      1393113600    NaN   NaN
# 2                                    kiding      1392595200    7.0   NaN
# 3                             missing pages      1392595200    3.0   NaN
# 4                        best study product      1381708800    NaN   NaN
# ..                                      ...             ...    ...   ...
# 95  better human japanese 1but much changed      1207612800   99.0   NaN
# 96                            great product      1206489600    4.0   NaN
# 97                                     love      1203465600    2.0   NaN
# 98                    outstanding easytouse      1202688000    5.0   NaN
# 99    learning foreign language human touch      1200700800  246.0   NaN
#
# [100 rows x 13 columns]

# %% [markdown]
# # Handling Emojis
#
# - If we have emojis in the text, we have two options:
#   - Removing Emojis. (OR)
#   - Replacing emojis in the form of text.

# %%
import re
def remove_emoji(text):
    emoji_pattern = re.compile("["
                               "u\U0001F600-\U0001F64F"  # Emotions
                               "u\U0001F300-\U0001F5FF"  # Symbols & pictographs
                               "u\U0001F680-\U0001F6FF"  # Transport & map symbols
                               "u\U0001F1E0-\U0001F1FF"  # Flags(iOS)
                               "u\U00002702-\U000027B0"
                               "u\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
remove_emoji("Loved the movie, it was 👍")

# %%
import emoji
print(emoji.demojize('Python is 🔥'))

# %% [markdown]
# # Tokenization

# %% [markdown]
# ### 1. Using the split function

# %%
# Word Tokenization
a = 'I am going to delhi'
a.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
# Sentence Tokenization
b = 'Iam going to delhi. I will stay there for 3 days. Let\'s hope the trip to be great'
b.split('.')
# Out:
# ['Iam going to delhi',
#  ' I will stay there for 3 days',
#  " Let's hope the trip to be great"]

# %%
# Problem with split function
c = 'I am going to delhi'
c.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
d = 'Where do think I should go? I have 3 day holiday'
d.split('.')
# Out:
# ['Where do think I should go? I have 3 day holiday']

# %% [markdown]
# ### 2. Regular Expression

# %%
import re

e = 'I am going to delhi'
tokens = re.findall("[\w']+", e)
tokens
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Sreedhar\AppData\Local\Temp\ipykernel_21824\2949696684.py:4: SyntaxWarning: invalid escape sequence '\w'
#   tokens = re.findall("[\w']+", e)
# ['I', 'am', 'going', 'to', 'delhi']

# %%
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""
sentences = re.compile('[.!?] ').split(text)
sentences
# Out:
# ["Lorem Ipsum is simply dummy text of the printing and typesetting industry?\nLorem Ipsum has been the industry's standard dummy text ever since the 1500s,\nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %% [markdown]
# ### 3. NLTK

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
sent1 = 'I am goind to visit delhi!'
word_tokenize(sent1)
# Out:
# ['I', 'am', 'goind', 'to', 'visit', 'delhi', '!']

# %%
text = """Lorem Ipsum is simply dummy text of the printing and typesetting industry?
Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,
when an unknown printer took a galley of type and scrambled it to make a type specimen book."""

sent_tokenize(text)
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry?',
#  "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s,\nwhen an unknown printer took a galley of type and scrambled it to make a type specimen book."]

# %%
sent5 = 'I have a Ph.D in A.I'
sent6 = "We're  here to help! mail us at gks@gmail.com"
sent7 = 'A 5km ride cost $10.50'

# %%
word_tokenize(sent5)
# Out:
# ['I', 'have', 'a', 'Ph.D', 'in', 'A.I']

# %%
word_tokenize(sent6)
# Out:
# ['We',
#  "'re",
#  'here',
#  'to',
#  'help',
#  '!',
#  'mail',
#  'us',
#  'at',
#  'gks',
#  '@',
#  'gmail.com']

# %%
word_tokenize(sent7)
# Out:
# ['A', '5km', 'ride', 'cost', '$', '10.50']

# %% [markdown]
# ### 4. Spacy

# %%
import spacy
nlp = spacy.load('en_core_web_sm') #english small dictionary

# %%
doc1 = nlp(sent5)
doc2 = nlp(sent6)
doc3 = nlp(sent7)
doc4 = nlp(sent1)

# %%
for token in doc1: # here it is failing
    print(token)
# Out:
# I
# have
# a
# Ph
# .
# D
# in
# A.I

# %%
for token in doc2:
    print(token)
# Out:
# We
# 're
#
# here
# to
# help
# !
# mail
# us
# at
# gks@gmail.com

# %%
for token in doc3:
    print(token)
# Out:
# A
# 5
# km
# ride
# cost
# $
# 10.50

# %%
for token in doc4:
    print(token)
# Out:
# I
# am
# goind
# to
# visit
# delhi
# !

# %% [markdown]
# # Stemming

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()
def stem_words(text):
    return " ".join([ps.stem(word) for word in text.split()])

# %%
sample = "walk walks walking walked"
stem_words(sample)
# Out:
# 'walk walk walk walk'

# %%
text = "probably my all time favourite movie a story of selflessness sacrifice and dedication to a noble cause but its not preachy or boring it just never gets old despite my having seen some 15 or more times in the last 25 years."
print(text)
# Out:
# probably my all time favourite movie a story of selflessness sacrifice and dedication to a noble cause but its not preachy or boring it just never gets old despite my having seen some 15 or more times in the last 25 years.

# %%
stem_words(text)
# Out:
# 'probabl my all time favourit movi a stori of selfless sacrific and dedic to a nobl caus but it not preachi or bore it just never get old despit my have seen some 15 or more time in the last 25 years.'

# %% [markdown]
# - Here after doing stemming the words like probably, movie, sacrifice etc are converted to probabl, movi, sacrific
# - To solve this issue we will do Lemmetization.
# - Work of both Stemming and Lemmetization are same.
# - The difference is, Lemmetization is slow compared to Stemming

# %% [markdown]
# # Lemmatizer

# %%
import nltk
from nltk.stem import WordNetLemmatizer

# %%
# Download the WordNet corpus
nltk.download('wordnet')

# You might also need to download the 'omw-1.4' package for wordnet
nltk.download('omw-1.4')
# Out:
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading omw-1.4: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
wordnet_lemmatizer = WordNetLemmatizer()

sentence = "He aws running and eating at same time. He has bad habit of swimming after playing long hours in the Sun."
punctuations = "?:!.,;"
sentence_words = nltk.word_tokenize(sentence)
for word in sentence_words:
    if word in punctuations:
        sentence_words.remove(word)
    
sentence_words
print("{0:20}{1:20}".format("Word","Lemma"))
for word in sentence_words:
    print("{0:20}{1:20}".format(word,wordnet_lemmatizer.lemmatize(word,pos='v')))
# Out:
# Word                Lemma
# He                  He
# aws                 aws
# running             run
# and                 and
# eating              eat
# at                  at
# same                same
# time                time
# He                  He
# has                 have
# bad                 bad
# habit               habit
# of                  of
# swimming            swim
# after               after
# playing             play
# long                long
# hours               hours
# in                  in
# the                 the
# Sun                 Sun
